# %% [markdown]
#      1 #include <iostream>
#      2  #include <cstdlib>
#      3  #include <ctime>
#      4
#      5  #define ROCK 1
#      6  #define PAPER 2
#      7  #define SCISSORS 3
#      8
#      9  using namespace std;
#     10
#     11  int main()
#     12  {
#     13      srand((unsigned int) time(NULL));
#     14
#     15      int player_throw = 0;
#     16      int ai_throw = 0;
#     17      bool draw = false;
#     18      char play_again;
#     19
#     20      do
#     21      {
#     22          cout << "Choose your move." << endl;
#     23          cout << "1) Rock" << endl;
#     24          cout << "2) Paper" << endl;
#     25          cout << "3) Scissors" << endl;
#     26          cout << "Your Move: ";
#     27          cin >> player_throw;
#     28
#     29          cout << endl;
#     30
#     31          ai_throw = (rand() % 3) + 1;
#     32
#     33          if (ai_throw == ROCK)
#     34          {
#     35              cout << "AI chooses Rock." << endl;
#     36          }
#     37          else if (ai_throw == PAPER)
#     38          {
#     39              cout << "AI chooses Paper." << endl;
#     40          }
#     41          else if (ai_throw == SCISSORS)
#     42          {
#     43              cout << "AI chooses Scissors." << endl;
#     44          }
#     45
#     46          draw = false;
#     47
#     48          if (player_throw == ai_throw)
#     49          {
#     50              draw = true;
#     51              cout << "It's a tie! Let's try again!" << endl;
#     52          }
#     53          else if (player_throw == ROCK && ai_throw == SCISSORS)
#     54          {
#     55              cout << "Rock smashes Scissors! You Win!" << endl;
#     56          }
#     57          else if (player_throw == ROCK && ai_throw == PAPER)
#     58          {
#     59              cout << "Paper covers Rock! You Lose!" << endl;
#     60          }
#     61          else if (player_throw == PAPER && ai_throw == ROCK)
#     62          {
#     63              cout << "Paper covers Rock! You Win!" << endl;
#     64          }
#     65          else if (player_throw == PAPER && ai_throw == SCISSORS)
#     66          {
#     67              cout << "Scissors cut Paper! You Lose!" << endl;
#     68          }
#     69          else if (player_throw == SCISSORS && ai_throw == PAPER)
#     70          {
#     71              cout << "Scissors cut Paper! You Win!" << endl;
#     72          }
#     73          else if (player_throw == SCISSORS && ai_throw == ROCK)
#     74          {
#     75              cout << "Rock smashes Scissors! You Lose!" << endl;
#     76          }
#     77
#     78          cout << endl;
#     79          cout << "Do you want to play again? (Y/N): ";
#     80          cin >> play_again;
#     81
#     82      } while (play_again == 'Y' || play_again == 'y');
#     83
#     84      cout << "Exiting the game. Goodbye!" << endl;
#     85
#     86      return 0;
#     87  }
